# %%
import cv2
import numpy as np

class VideoSynchronizer:
    def __init__(self, video1_path, video2_path):
        self.cap1 = cv2.VideoCapture(video1_path)
        self.cap2 = cv2.VideoCapture(video2_path)
        self.fps1 = self.cap1.get(cv2.CAP_PROP_FPS)
        self.fps2 = self.cap2.get(cv2.CAP_PROP_FPS)
        self.delay = self._calculate_delay()
        
    def _calculate_delay(self):
        """Определение задержки между видео через SIFT-дескрипторы"""
        sift = cv2.SIFT_create()
        
        # Поиск ключевых кадров
        kp1, des1 = self._get_key_frame(self.cap1, sift)
        kp2, des2 = self._get_key_frame(self.cap2, sift)
        
        # Сопоставление дескрипторов
        bf = cv2.BFMatcher()
        matches = bf.knnMatch(des1, des2, k=2)
        
        # Фильтрация по соотношению расстояний
        good = []
        for m,n in matches:
            if m.distance < 0.75*n.distance:
                good.append(m)
                
        # Расчет смещения в кадрах
        time_diff = len(good)/self.fps1
        return int(time_diff * self.fps2)

    def _get_key_frame(self, cap, detector):
        """Поиск кадра с максимальным числом особенностей"""
        max_features = 0
        best_frame = None
        for _ in range(30):  # Проверка первых 30 кадров
            ret, frame = cap.read()
            if not ret: break
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            kp, des = detector.detectAndCompute(gray, None)
            if len(kp) > max_features:
                max_features = len(kp)
                best_frame = (kp, des)
        return best_frame

    def get_sync_frames(self):
        """Генератор синхронизированных кадров"""
        self.cap2.set(cv2.CAP_PROP_POS_FRAMES, self.delay)
        
        while True:
            ret1, frame1 = self.cap1.read()
            ret2, frame2 = self.cap2.read()
            
            if not ret1 or not ret2:
                break
                
            yield frame1, frame2

# Использование
#syncer = VideoSynchronizer("video1.mp4", "video2.mp4")
#for frame1, frame2 in syncer.get_sync_frames():
 #   cv2.imshow('Sync', np.hstack((frame1, frame2)))
  #  if cv2.waitKey(25) & 0xFF == ord('q'):
   #     break


class StereoCalibrator:
    def __init__(self, chessboard_size=(9,6), square_size=2.5):
        self.chessboard_size = chessboard_size
        self.square_size = square_size
        self.obj_points = []
        self.img_points_left = []
        self.img_points_right = []
        
        # Подготовка 3D точек шахматки
        self.objp = np.zeros((chessboard_size[0]*chessboard_size[1],3), np.float32)
        self.objp[:,:2] = np.mgrid[0:chessboard_size[0],0:chessboard_size[1]].T.reshape(-1,2) * square_size

    def process_videos(self, video1, video2):
        syncer = VideoSynchronizer(video1, video2)
        criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.001)
        
        for frame1, frame2 in syncer.get_sync_frames():
            gray1 = cv2.cvtColor(frame1, cv2.COLOR_BGR2GRAY)
            gray2 = cv2.cvtColor(frame2, cv2.COLOR_BGR2GRAY)
            
            # Поиск углов
            ret1, corners1 = cv2.findChessboardCorners(gray1, self.chessboard_size, None)
            ret2, corners2 = cv2.findChessboardCorners(gray2, self.chessboard_size, None)
            
            if ret1 and ret2:
                corners1 = cv2.cornerSubPix(gray1, corners1, (11,11), (-1,-1), criteria)
                corners2 = cv2.cornerSubPix(gray2, corners2, (11,11), (-1,-1), criteria)
                
                self.obj_points.append(self.objp)
                self.img_points_left.append(corners1)
                self.img_points_right.append(corners2)
                
        # Индивидуальная калибровка
        ret, mtx1, dist1, _, _ = cv2.calibrateCamera(
            self.obj_points, self.img_points_left, gray1.shape[::-1], None, None)
        
        ret, mtx2, dist2, _, _ = cv2.calibrateCamera(
            self.obj_points, self.img_points_right, gray2.shape[::-1], None, None)
        
        # Стереокалибровка
        ret, mtx1, dist1, mtx2, dist2, R, T, E, F = cv2.stereoCalibrate(
            self.obj_points, self.img_points_left, self.img_points_right,
            mtx1, dist1, mtx2, dist2, gray1.shape[::-1],
            criteria=(cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 1e-5),
            flags=cv2.CALIB_FIX_INTRINSIC
        )
        
        return {
            'mtx1': mtx1, 'dist1': dist1,
            'mtx2': mtx2, 'dist2': dist2,
            'R': R, 'T': T,
            'E': E, 'F': F
        }

# Пример использования
calibrator = StereoCalibrator()
print("start")
params = calibrator.process_videos("left_cam.mp4", "right_cam.mp4")
np.savez("stereo_params.npz", **params)
print("finish")
# Out:
# start

# %%
import cv2
import numpy as np
import glob

class CameraCalibrator:
    def __init__(self, pattern_size=(7,7), square_size=0.025):
        self.pattern_size = pattern_size
        self.square_size = square_size
        self.obj_points = []
        self.img_points = []
        
        self.objp = np.zeros((pattern_size[0]*pattern_size[1],3), np.float32)
        self.objp[:,:2] = np.mgrid[0:pattern_size[0],0:pattern_size[1]].T.reshape(-1,2) * square_size

    def calibrate(self, images_folder):
        images = glob.glob(f"{images_folder}/*.jpg") + glob.glob(f"{images_folder}/*.png")
        
        if not images:
            raise FileNotFoundError(f"Нет изображений в папке {images_folder}!")
            
        criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.001)
        found = 0
        
        for fname in images:
            img = cv2.imread(fname)
            if img is None:
                continue
                
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            ret, corners = cv2.findChessboardCorners(gray, self.pattern_size, None)
            
            if ret:
                corners = cv2.cornerSubPix(gray, corners, (11,11), (-1,-1), criteria)
                self.obj_points.append(self.objp)
                self.img_points.append(corners)
                found += 1
                print(f"Найдено углов в {fname}")

        if found == 0:
            raise ValueError("Шахматная доска не найдена ни на одном изображении!")
            
        h, w = img.shape[:2]
        ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(
            self.obj_points, self.img_points, (w, h), None, None)
            
        print(f"\nУспешно обработано изображений: {found}/{len(images)}")
        return mtx, dist

# Пример использования
try:
    calibrator = CameraCalibrator(pattern_size=(7,7), square_size=0.025)
    mtx, dist = calibrator.calibrate("frames_all_left_cam_mihon")
    np.savez("left_cam_mihon_colib.npz", camera_matrix=mtx, dist_coeffs=dist)

    calibrator2 = CameraCalibrator(pattern_size=(7,7), square_size=0.025)
    mtx, dist = calibrator2.calibrate("frames_all_right_cam_danya")
    np.savez("right_cam_danya_colib.npz", camera_matrix=mtx, dist_coeffs=dist)
except Exception as e:
    print(f"Ошибка: {e}")
# Out:
# Найдено углов в frames_all_left_cam_mihon\frame_0000.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0001.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0002.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0003.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0004.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0005.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0006.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0007.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0008.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0009.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0010.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0011.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0012.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0013.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0014.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0015.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0016.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0017.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0018.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0019.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0020.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0021.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0022.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0023.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0024.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0025.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0026.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0027.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0028.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0029.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0030.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0031.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0032.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0033.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0034.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0035.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0036.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0037.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0038.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0039.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0040.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0041.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0042.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0043.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0044.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0045.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0046.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0047.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0048.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0049.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0050.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0051.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0052.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0053.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0054.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0055.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0056.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0057.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0058.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0059.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0060.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0061.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0062.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0063.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0064.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0065.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0066.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0067.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0068.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0069.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0070.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0071.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0072.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0073.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0074.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0075.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0076.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0077.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0078.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0079.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0080.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0081.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0082.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0083.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0084.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0085.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0086.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0087.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0088.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0089.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0090.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0091.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0092.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0093.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0094.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0095.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0096.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0097.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0098.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0099.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0100.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0101.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0102.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0103.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0104.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0105.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0106.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0107.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0108.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0109.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0110.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0111.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0112.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0113.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0114.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0115.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0116.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0117.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0118.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0119.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0120.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0121.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0122.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0123.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0124.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0125.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0126.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0127.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0128.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0129.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0130.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0131.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0132.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0133.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0134.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0135.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0136.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0137.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0138.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0139.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0140.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0141.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0142.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0143.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0144.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0145.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0146.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0147.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0148.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0149.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0150.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0151.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0152.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0153.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0154.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0155.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0156.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0157.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0158.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0159.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0160.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0161.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0162.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0163.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0164.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0165.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0166.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0167.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0168.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0169.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0170.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0171.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0172.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0173.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0174.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0175.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0176.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0177.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0178.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0179.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0180.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0181.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0182.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0183.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0184.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0185.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0186.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0187.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0188.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0189.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0190.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0191.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0192.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0193.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0194.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0195.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0196.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0197.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0198.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0199.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0200.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0201.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0202.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0203.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0204.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0205.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0206.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0207.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0208.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0209.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0210.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0211.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0212.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0213.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0214.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0215.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0216.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0217.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0218.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0219.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0220.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0221.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0222.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0223.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0224.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0225.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0226.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0227.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0228.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0229.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0230.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0231.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0232.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0233.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0234.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0235.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0236.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0237.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0238.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0239.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0240.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0241.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0242.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0243.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0244.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0245.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0246.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0247.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0248.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0249.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0250.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0251.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0252.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0253.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0254.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0255.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0256.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0257.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0258.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0259.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0260.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0261.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0262.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0263.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0264.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0265.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0266.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0267.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0268.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0269.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0270.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0271.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0272.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0273.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0274.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0275.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0276.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0277.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0278.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0279.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0280.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0281.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0282.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0283.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0284.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0285.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0286.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0287.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0288.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0289.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0290.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0291.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0292.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0293.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0294.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0295.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0296.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0297.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0298.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0299.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0300.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0301.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0302.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0303.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0304.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0305.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0306.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0307.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0308.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0309.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0310.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0311.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0312.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0313.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0314.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0315.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0316.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0317.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0318.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0319.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0320.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0321.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0322.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0323.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0324.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0325.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0326.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0327.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0328.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0329.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0330.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0331.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0332.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0333.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0334.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0335.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0336.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0337.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0338.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0339.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0340.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0341.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0342.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0343.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0344.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0345.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0346.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0347.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0348.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0349.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0350.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0351.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0352.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0353.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0354.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0355.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0356.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0357.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0358.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0359.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0360.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0361.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0362.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0363.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0364.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0365.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0366.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0367.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0368.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0369.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0370.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0371.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0372.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0373.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0374.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0375.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0376.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0377.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0378.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0379.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0380.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0381.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0382.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0383.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0384.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0385.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0386.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0387.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0388.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0389.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0390.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0391.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0392.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0393.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0394.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0395.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0396.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0397.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0398.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0399.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0400.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0401.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0402.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0403.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0404.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0405.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0406.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0407.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0408.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0409.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0440.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0441.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0442.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0443.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0444.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0445.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0446.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0447.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0448.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0449.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0450.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0451.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0452.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0453.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0454.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0455.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0456.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0457.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0458.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0459.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0460.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0461.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0462.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0463.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0464.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0465.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0466.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0467.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0468.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0469.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0470.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0471.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0472.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0473.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0474.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0475.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0476.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0477.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0478.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0479.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0480.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0481.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0482.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0483.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0484.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0485.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0486.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0487.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0488.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0489.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0490.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0491.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0492.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0493.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0494.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0495.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0496.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0497.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0498.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0499.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0500.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0501.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0502.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0503.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0504.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0505.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0506.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0507.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0508.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0509.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0510.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0511.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0512.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0513.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0514.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0515.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0516.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0517.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0518.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0519.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0520.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0521.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0522.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0523.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0524.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0525.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0526.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0527.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0528.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0529.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0530.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0531.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0532.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0533.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0534.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0535.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0536.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0537.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0538.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0539.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0540.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0541.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0542.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0543.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0544.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0545.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0546.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0547.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0548.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0549.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0550.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0551.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0552.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0553.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0554.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0555.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0556.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0557.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0558.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0559.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0560.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0561.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0562.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0563.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0564.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0565.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0566.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0567.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0568.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0569.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0570.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0571.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0572.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0573.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0574.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0583.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0584.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0585.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0586.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0587.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0588.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0589.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0590.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0591.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0592.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0593.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0594.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0595.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0596.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0597.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0598.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0599.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0600.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0601.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0602.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0603.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0604.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0605.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0606.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0607.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0608.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0609.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0610.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0611.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0612.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0613.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0614.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0615.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0616.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0617.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0618.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0619.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0620.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0621.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0622.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0623.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0624.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0625.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0626.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0627.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0628.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0629.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0630.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0631.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0632.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0633.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0634.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0635.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0636.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0637.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0638.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0639.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0640.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0641.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0642.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0643.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0644.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0645.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0646.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0647.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0648.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0649.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0650.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0651.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0652.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0653.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0654.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0655.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0656.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0657.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0658.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0659.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0660.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0661.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0662.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0663.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0664.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0665.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0666.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0667.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0668.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0669.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0670.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0671.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0672.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0673.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0674.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0675.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0676.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0677.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0678.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0679.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0680.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0681.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0682.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0683.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0684.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0685.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0686.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0687.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0688.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0689.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0690.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0691.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0692.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0693.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0694.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0695.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0696.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0697.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0698.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0699.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0700.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0701.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0702.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0703.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0704.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0705.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0706.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0707.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0708.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0709.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0710.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0711.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0712.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0713.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0714.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0715.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0716.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0717.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0718.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0719.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0720.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0721.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0722.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0723.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0724.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0725.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0726.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0727.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0728.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0729.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0730.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0790.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0791.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0792.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0793.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0794.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0795.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0796.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0797.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0798.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0799.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0800.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0801.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0802.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0803.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0804.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0805.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0806.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0807.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0808.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0809.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0810.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0811.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0812.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0813.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0814.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0815.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0816.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0817.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0818.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0819.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0820.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0821.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0822.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0823.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0824.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0825.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0826.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0827.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0828.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0829.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0830.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0831.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0832.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0833.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0834.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0835.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0836.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0837.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0838.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0839.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0840.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0841.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0842.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0843.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0844.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0845.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0846.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0847.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0848.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0849.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0850.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0851.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0852.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0853.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0854.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0855.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0856.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0857.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0858.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0859.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0860.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0861.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0862.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0863.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0864.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0865.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0866.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0867.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0868.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0869.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0870.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0871.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0872.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0873.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0874.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0875.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0876.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0877.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0878.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0879.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0880.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0881.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0882.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0883.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0884.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0885.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0886.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0887.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0888.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0889.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0890.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0891.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0892.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0893.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0894.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0895.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0896.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0897.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0898.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0899.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0900.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0901.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0902.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0903.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0904.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0905.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0906.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0907.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0908.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0909.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0910.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0911.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0912.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0913.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0914.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0915.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0916.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0917.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0918.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0919.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0920.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0921.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0922.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0923.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0924.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0925.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0926.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0927.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0928.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0929.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0930.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0931.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0932.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0933.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0934.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0935.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0936.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0937.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0938.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0939.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0940.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0941.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0942.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0943.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0944.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0945.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0946.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0947.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0948.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0949.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0950.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0951.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0952.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0953.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0954.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0955.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0956.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0957.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0958.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0959.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0960.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0961.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0962.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0963.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0964.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0965.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0966.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0967.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0968.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0969.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0970.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0971.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0972.jpg
# Найдено углов в frames_all_left_cam_mihon\frame_0973.jpg

# %%
import numpy as np
import cv2
import os

def print_calibration_metrics(calib_file):
    # Проверка существования файла
    if not os.path.exists(calib_file):
        print(f"Файл {calib_file} не найден!")
        print("Доступные файлы в текущей директории:")
        print(os.listdir())
        return
    
    data = np.load(calib_file)
    
    print("\n=== Camera Matrix ===")
    print(data['camera_matrix'])
    
    print("\n=== Distortion Coefficients ===")
    print(data['dist_coeffs'])
    
    # Расчет фокусного расстояния
    fx = data['camera_matrix'][0,0]
    fy = data['camera_matrix'][1,1]
    print(f"\nFocal Length (fx): {fx:.1f} px")
    print(f"Focal Length (fy): {fy:.1f} px")
    
    # Оптический центр
    cx = data['camera_matrix'][0,2]
    cy = data['camera_matrix'][1,2]
    print(f"Optical Center: ({cx:.1f}, {cy:.1f})")

# Проверяем существование файлов перед вызовом
print("Проверка файлов:")
print("left_cam_mihon_colib.npz exists:", os.path.exists("left_cam_mihon_colib.npz"))
print("right_cam_calib.npz exists:", os.path.exists("right_cam_calib.npz"))

# Пример использования
print("\nleft_cam info:")
print_calibration_metrics("left_cam_mihon_colib.npz")  # Исправлено имя файла

print("\nright_cam info:")
print_calibration_metrics("right_cam_calib.npz")
# Out:
# Проверка файлов:
# left_cam_mihon_colib.npz exists: True
# right_cam_calib.npz exists: True
#
# left_cam info:
#
# === Camera Matrix ===
# [[733.69078545   0.         232.164899  ]
#  [  0.         748.83031112 423.89795623]
#  [  0.           0.           1.        ]]
#
# === Distortion Coefficients ===
# [[ 1.12119763e-01  6.22426262e-01  3.74884748e-04 -1.85916773e-03
#   -3.03870070e+00]]
#
# Focal Length (fx): 733.7 px
# Focal Length (fy): 748.8 px
# Optical Center: (232.2, 423.9)
#
# right_cam info:
#
# === Camera Matrix ===
# [[983.58100649   0.         478.97924058]
#  [  0.         983.88686381 644.65400484]
#  [  0.           0.           1.        ]]
#
# === Distortion Coefficients ===
# [[ 1.97392074e-01 -1.30238448e+00  1.12036419e-03  6.39925513e-04
#    2.63344168e+00]]
#
# Focal Length (fx): 983.6 px
# Focal Length (fy): 983.9 px
# Optical Center: (479.0, 644.7)

# %%
import cv2
import numpy as np
from sort import Sort
from ultralytics import YOLO
import torch

class StereoDistanceCalculator:
    def __init__(self, left_calib, right_calib, baseline=0.25):
        self.left_params = np.load(left_calib)
        self.right_params = np.load(right_calib)
        
        # Инициализация стереоалгоритма с оптимальными параметрами
        self.stereo = cv2.StereoSGBM_create(
            minDisparity=0,
            numDisparities=128,    # Должно быть кратно 16
            blockSize=5,
            P1=8*3*5**2,
            P2=32*3*5**2,
            disp12MaxDiff=5,
            uniquenessRatio=15,
            speckleWindowSize=50,
            speckleRange=2,
            mode=cv2.STEREO_SGBM_MODE_SGBM_3WAY
        )
        
        self.baseline = baseline
        self.focal_length = np.mean([
            self.left_params['camera_matrix'][0,0],
            self.right_params['camera_matrix'][0,0]
        ])

    def _preprocess_images(self, left, right):
        # Приведение к одинаковому размеру
        h, w = left.shape[:2]
        right = cv2.resize(right, (w, h))
        
        # Конвертация в grayscale
        left_gray = cv2.cvtColor(left, cv2.COLOR_BGR2GRAY)
        right_gray = cv2.cvtColor(right, cv2.COLOR_BGR2GRAY)
        
        # Удаление дисторсии
        left_rect = cv2.undistort(left_gray, 
                                self.left_params['camera_matrix'],
                                self.left_params['dist_coeffs'])
        right_rect = cv2.undistort(right_gray,
                                 self.right_params['camera_matrix'],
                                 self.right_params['dist_coeffs'])
        
        return left_rect, right_rect

    def calculate_distance(self, left_frame, right_frame, bbox):
        try:
            # Проверка входных данных
            if left_frame is None or right_frame is None:
                raise ValueError("Пустой кадр")
                
            if left_frame.shape != right_frame.shape:
                left_frame = cv2.resize(left_frame, (right_frame.shape[1], right_frame.shape[0]))
                
            # Предобработка изображений
            left_rect, right_rect = self._preprocess_images(left_frame, right_frame)

            cv2.imshow('1', left_rect)
            cv2.imshow('2', right_rect)  #проверка что в кадре
            cv2.waitKey(0)
            cv2.destroyAllWindows()

            
            # Вычисление диспарантности
            disparity = self.stereo.compute(left_rect, right_rect)
            
            # Фильтрация шумов
            disparity = cv2.medianBlur(disparity, 5)
            disparity = np.abs(disparity)
            
            # Расчет расстояния для ROI
            x1, y1, x2, y2 = map(int, bbox)
            roi = disparity[y1:y2, x1:x2]
            valid_disp = roi[roi > 0]
            
            if valid_disp.size == 0:
                return 0.0
                
            avg_disp = np.mean(valid_disp)
            Z = (self.focal_length * self.baseline) / (avg_disp + 1e-6)
            return Z
            
        except Exception as e:
            print(f"Ошибка расчета расстояния: {str(e)}")
            return 0.0

class ObjectDetection:
    def __init__(self, video_left, video_right, output_file="output_.avi"):
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        print("Using Device: ", self.device)
        self.cap_left = cv2.VideoCapture(video_left)
        self.cap_right = cv2.VideoCapture(video_right)
        self.model = YOLO("yolov8m.pt")
        self.tracker = Sort(max_age=50, min_hits=8, iou_threshold=0.50)
        
        # Инициализация модуля расчета расстояний
        self.distance_calculator = StereoDistanceCalculator(
            "left_cam_diman_calib.npz",
            "right_cam_mihon_colib.npz",
            baseline=0.19  # Ваше измеренное расстояние между камерами
        )
        
        self.trajectories = {}
        self.speed_history = {}

    def process_frame(self):
        ret_left, left_frame = self.cap_left.read()
        ret_right, right_frame = self.cap_right.read()
        if not ret_left or not ret_right: return None
        
        results = self.model(left_frame)
        boxes = results[0].boxes.xyxy.cpu().numpy()
        confidences = results[0].boxes.conf.cpu().numpy()
        classes = results[0].boxes.cls.cpu().numpy()
        
        # Фильтрация объектов
        detected_objects = []
        for box, conf, cls in zip(boxes, confidences, classes):
            detected_objects.append([*box, conf])
        
        tracks = self.tracker.update(np.array(detected_objects))
        
        # Расчет расстояний и отрисовка
        for track in tracks:
            x1, y1, x2, y2, track_id = map(int, track)
            bbox = [x1, y1, x2, y2]
            
            try:
                distance = self.distance_calculator.calculate_distance(
                    left_frame, right_frame, bbox)
                
                # Отрисовка рамки и информации
                cv2.rectangle(left_frame, (x1,y1), (x2,y2), (0,255,0), 2)
                cv2.putText(left_frame, f"ID:{track_id} Dist:{distance:.2f}m",
                          (x1, y1-10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,0,0), 2)
            except Exception as e:
                print(f"Ошибка расчета расстояния: {e}")
        
        return left_frame

    def run(self):
        while True:
            frame = self.process_frame()
            if frame is None: break
            
            cv2.imshow('Stereo Detection', frame)
            if cv2.waitKey(1) == ord('q'): break
        
        self.cap_left.release()
        self.cap_right.release()
        cv2.destroyAllWindows()

# Запуск системы
detector = ObjectDetection("http://192.168.0.100:4747/video", "http://192.168.0.103:4747/video")
detector.run()
# Out:
# Using Device:  cuda
#
# 0: 480x640 1 cup, 1 refrigerator, 58.7ms
# Speed: 0.0ms preprocess, 58.7ms inference, 129.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 237.3ms
# Speed: 2.0ms preprocess, 237.3ms inference, 15.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 175.0ms
# Speed: 1.5ms preprocess, 175.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 26.1ms
# Speed: 0.0ms preprocess, 26.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 213.3ms
# Speed: 0.0ms preprocess, 213.3ms inference, 15.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 190.7ms
# Speed: 0.0ms preprocess, 190.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 174.8ms
# Speed: 4.1ms preprocess, 174.8ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cups, 1 refrigerator, 19.2ms
# Speed: 2.0ms preprocess, 19.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cups, 1 refrigerator, 24.0ms
# Speed: 0.0ms preprocess, 24.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 microwave, 1 refrigerator, 24.9ms
# Speed: 0.0ms preprocess, 24.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 6.4ms
# Speed: 5.3ms preprocess, 6.4ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cups, 1 refrigerator, 75.1ms
# Speed: 0.0ms preprocess, 75.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 79.0ms
# Speed: 0.0ms preprocess, 79.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 microwave, 1 refrigerator, 71.6ms
# Speed: 0.0ms preprocess, 71.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 microwave, 1 refrigerator, 79.4ms
# Speed: 0.0ms preprocess, 79.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 microwave, 1 refrigerator, 71.5ms
# Speed: 7.7ms preprocess, 71.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 77.2ms
# Speed: 0.0ms preprocess, 77.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 71.5ms
# Speed: 2.0ms preprocess, 71.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 microwave, 1 refrigerator, 67.7ms
# Speed: 2.0ms preprocess, 67.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 microwaves, 1 refrigerator, 80.6ms
# Speed: 0.0ms preprocess, 80.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 microwave, 1 refrigerator, 62.9ms
# Speed: 4.1ms preprocess, 62.9ms inference, 16.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 70.0ms
# Speed: 4.0ms preprocess, 70.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 189.3ms
# Speed: 1.7ms preprocess, 189.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 8.7ms
# Speed: 2.0ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 25.7ms
# Speed: 0.0ms preprocess, 25.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 microwave, 1 refrigerator, 21.0ms
# Speed: 0.0ms preprocess, 21.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 microwaves, 1 refrigerator, 71.2ms
# Speed: 8.3ms preprocess, 71.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 172.9ms
# Speed: 2.0ms preprocess, 172.9ms inference, 8.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 14.4ms
# Speed: 0.0ms preprocess, 14.4ms inference, 10.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cups, 1 refrigerator, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cups, 1 refrigerator, 15.8ms
# Speed: 15.9ms preprocess, 15.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cups, 1 refrigerator, 76.4ms
# Speed: 2.0ms preprocess, 76.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 79.2ms
# Speed: 0.0ms preprocess, 79.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 microwave, 1 refrigerator, 83.9ms
# Speed: 0.0ms preprocess, 83.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 63.8ms
# Speed: 16.0ms preprocess, 63.8ms inference, 17.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 microwave, 1 refrigerator, 77.7ms
# Speed: 4.1ms preprocess, 77.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 81.0ms
# Speed: 0.0ms preprocess, 81.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 microwave, 1 refrigerator, 79.4ms
# Speed: 0.0ms preprocess, 79.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 microwave, 1 refrigerator, 183.6ms
# Speed: 7.7ms preprocess, 183.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 microwave, 1 refrigerator, 23.2ms
# Speed: 2.0ms preprocess, 23.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 microwave, 1 refrigerator, 22.1ms
# Speed: 9.7ms preprocess, 22.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 26.0ms
# Speed: 0.0ms preprocess, 26.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 27.3ms
# Speed: 0.0ms preprocess, 27.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 19.6ms
# Speed: 2.0ms preprocess, 19.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 31.6ms
# Speed: 0.0ms preprocess, 31.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 microwave, 1 refrigerator, 22.1ms
# Speed: 0.0ms preprocess, 22.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 25.7ms
# Speed: 0.0ms preprocess, 25.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 microwave, 1 refrigerator, 73.0ms
# Speed: 0.0ms preprocess, 73.0ms inference, 15.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 68.3ms
# Speed: 8.9ms preprocess, 68.3ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 microwave, 1 refrigerator, 75.5ms
# Speed: 4.0ms preprocess, 75.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 67.7ms
# Speed: 4.0ms preprocess, 67.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 66.3ms
# Speed: 5.7ms preprocess, 66.3ms inference, 15.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 169.8ms
# Speed: 5.5ms preprocess, 169.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 25.7ms
# Speed: 0.0ms preprocess, 25.7ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 15.7ms
# Speed: 16.1ms preprocess, 15.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 11.8ms
# Speed: 0.0ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 21.9ms
# Speed: 15.7ms preprocess, 21.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cups, 1 refrigerator, 82.8ms
# Speed: 0.0ms preprocess, 82.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 92.1ms
# Speed: 0.0ms preprocess, 92.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 70.4ms
# Speed: 0.0ms preprocess, 70.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 187.7ms
# Speed: 3.0ms preprocess, 187.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 63.3ms
# Speed: 16.0ms preprocess, 63.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 microwave, 1 refrigerator, 70.9ms
# Speed: 0.0ms preprocess, 70.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 67.3ms
# Speed: 15.7ms preprocess, 67.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 75.3ms
# Speed: 0.0ms preprocess, 75.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 79.3ms
# Speed: 0.0ms preprocess, 79.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 158.4ms
# Speed: 3.1ms preprocess, 158.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 78.9ms
# Speed: 0.0ms preprocess, 78.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 62.9ms
# Speed: 15.7ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 72.9ms
# Speed: 8.0ms preprocess, 72.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 189.6ms
# Speed: 0.0ms preprocess, 189.6ms inference, 13.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 microwave, 1 refrigerator, 178.3ms
# Speed: 5.1ms preprocess, 178.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 31.6ms
# Speed: 0.0ms preprocess, 31.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 15.7ms
# Speed: 0.0ms preprocess, 15.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 59.1ms
# Speed: 0.0ms preprocess, 59.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 95.8ms
# Speed: 4.4ms preprocess, 95.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 102.0ms
# Speed: 2.0ms preprocess, 102.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 2 microwaves, 1 refrigerator, 79.2ms
# Speed: 8.2ms preprocess, 79.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cups, 2 microwaves, 1 refrigerator, 174.6ms
# Speed: 0.0ms preprocess, 174.6ms inference, 15.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 microwave, 1 refrigerator, 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 2 microwaves, 1 refrigerator, 15.7ms
# Speed: 1.8ms preprocess, 15.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 68.7ms
# Speed: 10.4ms preprocess, 68.7ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 71.0ms
# Speed: 0.0ms preprocess, 71.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 microwave, 1 refrigerator, 73.5ms
# Speed: 4.0ms preprocess, 73.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 microwave, 1 refrigerator, 81.4ms
# Speed: 0.0ms preprocess, 81.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 microwave, 1 refrigerator, 132.8ms
# Speed: 10.5ms preprocess, 132.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 71.7ms
# Speed: 7.8ms preprocess, 71.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 71.9ms
# Speed: 0.0ms preprocess, 71.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 71.2ms
# Speed: 7.9ms preprocess, 71.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 79.1ms
# Speed: 0.0ms preprocess, 79.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 79.4ms
# Speed: 0.0ms preprocess, 79.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 70.9ms
# Speed: 5.0ms preprocess, 70.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 64.0ms
# Speed: 15.7ms preprocess, 64.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cups, 1 refrigerator, 77.7ms
# Speed: 0.0ms preprocess, 77.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 74.7ms
# Speed: 0.0ms preprocess, 74.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 175.0ms
# Speed: 9.8ms preprocess, 175.0ms inference, 15.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 15.8ms
# Speed: 0.0ms preprocess, 15.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 13.8ms
# Speed: 0.0ms preprocess, 13.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 80.8ms
# Speed: 15.8ms preprocess, 80.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 75.0ms
# Speed: 4.0ms preprocess, 75.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 176.6ms
# Speed: 7.9ms preprocess, 176.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 microwave, 1 refrigerator, 31.9ms
# Speed: 0.0ms preprocess, 31.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 microwaves, 1 refrigerator, 21.6ms
# Speed: 0.0ms preprocess, 21.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 microwave, 1 refrigerator, 17.7ms
# Speed: 0.0ms preprocess, 17.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 79.1ms
# Speed: 0.0ms preprocess, 79.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 186.9ms
# Speed: 13.7ms preprocess, 186.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 31.6ms
# Speed: 0.0ms preprocess, 31.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 microwave, 1 refrigerator, 15.8ms
# Speed: 0.0ms preprocess, 15.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 microwave, 1 refrigerator, 191.1ms
# Speed: 5.6ms preprocess, 191.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 31.8ms
# Speed: 0.0ms preprocess, 31.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 31.6ms
# Speed: 0.0ms preprocess, 31.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 31.9ms
# Speed: 0.0ms preprocess, 31.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 19.1ms
# Speed: 0.0ms preprocess, 19.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cups, 1 refrigerator, 26.9ms
# Speed: 0.0ms preprocess, 26.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 19.1ms
# Speed: 0.0ms preprocess, 19.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 9.9ms
# Speed: 0.0ms preprocess, 9.9ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 78.9ms
# Speed: 0.0ms preprocess, 78.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 39.8ms
# Speed: 4.1ms preprocess, 39.8ms inference, 10.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 47.6ms
# Speed: 2.8ms preprocess, 47.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 62.4ms
# Speed: 0.0ms preprocess, 62.4ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 1 refrigerator, 84.6ms
# Speed: 2.0ms preprocess, 84.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 75.7ms
# Speed: 2.0ms preprocess, 75.7ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 82.8ms
# Speed: 3.8ms preprocess, 82.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 microwave, 1 refrigerator, 84.8ms
# Speed: 0.0ms preprocess, 84.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 72.3ms
# Speed: 4.0ms preprocess, 72.3ms inference, 9.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 79.6ms
# Speed: 2.0ms preprocess, 79.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
